# %%
import pandas as pd
import numpy as np 
import math as math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://data.wprdc.org/datastore/dump/43f40ca4-2211-4a12-8b4f-4d052662bb64")

# %%
df.head()
# Out:
#            id                                     name  \
# 0   326501686                          10 Wakefield St
# 1   527853474                        1005 St Martin St
# 2  1074700399                        1017 St Martin St
# 3    50987987  30th St from Bigelow Blvd to Leander St
# 4   173445306    30th St from Paulowna to Bigelow Blvd
#
#   maintenance_responsibility   installed  material  length  number_of_steps  \
# 0               3rd Division         NaN  Concrete    53.0              8.0
# 1               4th Division         NaN  Concrete    33.0             24.0
# 2               4th Division         NaN  Concrete    52.0              4.0
# 3               3rd Division  1948-01-01  Concrete   106.0            106.0
# 4               6th Division  1948-01-01  Concrete   204.0             85.0
#
#    schools_count  school_score  total_population  ...       neighborhood  \
# 0            0.0         100.0             367.0  ...      South Oakland
# ...

# %%
neighborhoodCounts = pd.DataFrame(df['neighborhood'].value_counts())
neighborhoodCounts.rename(columns = {'neighborhood':'Stairways'}, inplace = True)
neighborhoodCounts.head(60)
# Out:
#                           Stairways
# South Side Slopes               106
# Mount Washington                 51
# Beechview                        42
# Greenfield                       40
# Perry North                      37
# Brookline                        36
# Sheraden                         34
# Perry South                      33
# Elliott                          33
# Carrick                          33
# Marshall-Shadeland               31
# Beltzhoover                      27
# Squirrel Hill South              24
# Duquesne Heights                 22
# Hazelwood                        21
# Highland Park                    21
# Allentown                        19
# Polish Hill                      19
# Spring Hill-City View            19
# Overbrook                        17
# Fineview                         17
# Upper Hill                       16
# Arlington                        15
# Troy Hill                        15
# Westwood                         14
# ...

# %%
neighborhoodCounts.head(65).plot.bar()
plt.rcParams["figure.figsize"] = (30,20)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Conclusion:** My dataset looks at the number of stairwells in Pittsburgh. My overall conclusion is trying to show which area is best based on health and this dataset displays exercise. Typically, stairwells are seen as something that is undesirable, but when it comes to life and death, the unintentional exercise due to stairwells can be the difference. To illustrate this, I chose to use a bar graph showing the areas with the most stairwells. Given this point of view, I concluded from my data set that the best neighborhood in Allegheny County is South Side Slopes. It had by far the most stairwells, doubling that of the neighborhood with the second most stairs (Mount Washington). The worst neighborhood in this regard is Shady Side, it has the least number of stairwells.
