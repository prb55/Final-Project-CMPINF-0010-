# %%
import pandas as pd
import numpy as np

# %%
dtype={'police_zone': 'string'}
low_memory=False

pgh_trees_data = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da",index_col="id")
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            address_number         street         common_name  \
# id
# 754166088            7428  MONTICELLO ST               Stump
# 1946899269            220     BALVER AVE  Linden: Littleleaf
# 1431517397           2822      SIDNEY ST          Maple: Red
# 994063598             608     SUISMON ST      Maple: Freeman
# 1591838573           1135   N NEGLEY AVE       Maple: Norway
#
#              scientific_name  height  width  growth_space_length  \
# id
# 754166088              Stump     0.0    0.0                 10.0
# 1946899269     Tilia cordata     0.0    0.0                 99.0
# 1431517397       Acer rubrum    22.0    6.0                  6.0
# 994063598   Acer x freemanii    25.0   10.0                  3.0
# 1591838573  Acer platanoides    52.0   13.0                 99.0
#
#             growth_space_width     growth_space_type  diameter_base_height  \
# id
# 754166088                  2.0           Well or Pit                  16.0
# 1946899269                99.0  Open or Unrestricted                  22.0
# 1431517397                 3.0           Well or Pit                   6.0
# 994063598                  3.0           Well or Pit                   7.0
# 1591838573                99.0  Open or Unrestricted                  38.0
#
#             ...      neighborhood council_district  ward         tract  \
# id          ...
# 754166088   ...    Homewood North              9.0  13.0  4.200313e+10
# 1946899269  ...           Oakwood              2.0  28.0  4.200356e+10
# 1431517397  ...  South Side Flats              3.0  16.0  4.200316e+10
# 994063598   ...    East Allegheny              1.0  23.0  4.200356e+10
# 1591838573  ...     Highland Park              7.0  11.0  4.200311e+10
#
#             public_works_division  pli_division  police_zone  fire_zone  \
# id
# 754166088                     2.0          13.0          5.0       3-17
# 1946899269                    5.0          28.0          6.0       1-19
# 1431517397                    3.0          16.0          3.0       4-24
# 994063598                     1.0          23.0          1.0        1-6
# 1591838573                    2.0          11.0          5.0        3-9
#
#              latitude  longitude
# id
# 754166088   40.458169 -79.889724
# 1946899269  40.429269 -80.067868
# 1431517397  40.426797 -79.965035
# 994063598   40.455503 -79.999276
# 1591838573  40.476667 -79.924106
#
# [5 rows x 57 columns]

# %%
# Creating a query mask that consists of only the police zone 
query_mask = pgh_trees_data[['police_zone']]

# Loops through the dataset and counts up every instance of a tree in each zone, prints it out
zone_1 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 1):
        zone_1 = zone_1 + 1    
print("Total number of trees in zone 1:" , 45710 - zone_1)

zone_2 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 2):
        zone_2 = zone_2 + 1    
print("Total number of trees in zone 2:" , 45710 - zone_2)

zone_3 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 3):
        zone_3 = zone_3 + 1    
print("Total number of trees in zone 3:" , 45710 - zone_3)

zone_4 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 4):
        zone_4 = zone_4 + 1    
print("Total number of trees in zone 4:" , 45710 - zone_4)

zone_5 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 5):
        zone_5 = zone_5 + 1    
print("Total number of trees in zone 5:" , 45710 - zone_5)

zone_6 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 6):
        zone_6 = zone_6 + 1    
print("Total number of trees in zone 6:" , 45710 - zone_6)


#zone 1 - brighton heights, manchesster, perry south
#zone 2 - polish hill, hill district, strip district, downtown
#zone 3 - south side, mt washington
#zone 4 - squirrel hill north and south
#zone 5 - east liberty and highland park
#zone 6 - crafton heights, elliott, duquesne heights
# Out:
# Total number of trees in zone 1: 7186
# Total number of trees in zone 2: 5124
# Total number of trees in zone 3: 4866
# Total number of trees in zone 4: 14576
# Total number of trees in zone 5: 10161
# Total number of trees in zone 6: 3543

# %%
#my_plot = query_mask.plot(kind='bar')

#my_plot.set_xlabel("Police Zones")
#my_plot.set_ylabel("Number of Trees")

df1 = pd.DataFrame({'Police Zone' : [1.,2.,3.,4.,5.,6.] ,'Number of Trees' : [7186., 5124., 4866., 14576., 10161., 3543.]})

my_plot=  df1.plot(kind='bar')

# %% [markdown]
# This dataset did not group by specific neighborhood, but it did specify which police zones each tree is located in. Here is a key for which police zones correlate to each Pittsburgh neighborhood:
#
# Zone 1 - Brighton Heights, Manchesster, Perry South
# Zone 2 - Polish Hill, Hill District, Strip District, Downtown
# Zone 3 - South Side and Mt. Washington
# Zone 4 - Squirrel Hill North and South
# Zone 5 - East Liberty and Highland Park
# Zone 6 - Crafton Heights, Elliott, Duquesne Heights

# %% [markdown]
# There are the most trees in police zone 4 of Pittsburgh, which correlates to the Squirrel Hill neighborhood. This leads me to make my personal conclusion that Squirrel Hill is the best neighborhood in Pittsburgh based off of this metric. Since there are significantly more trees in Squirrel Hill than most of the other Pittsburgh neighborhoods, Squirrel Hill will likely have better air quality, more parks, and overall a healthier lifestyle for the people who live there.
