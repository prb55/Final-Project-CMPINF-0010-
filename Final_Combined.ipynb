# %% [markdown]
# **Adnaan's Dataset:**

# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://data.wprdc.org/datastore/dump/43f40ca4-2211-4a12-8b4f-4d052662bb64")
df.head()
# Out:
#            id                                     name  \
# 0   326501686                          10 Wakefield St
# 1   527853474                        1005 St Martin St
# 2  1074700399                        1017 St Martin St
# 3    50987987  30th St from Bigelow Blvd to Leander St
# 4   173445306    30th St from Paulowna to Bigelow Blvd
#
#   maintenance_responsibility   installed  material  length  number_of_steps  \
# 0               3rd Division         NaN  Concrete    53.0              8.0
# 1               4th Division         NaN  Concrete    33.0             24.0
# 2               4th Division         NaN  Concrete    52.0              4.0
# 3               3rd Division  1948-01-01  Concrete   106.0            106.0
# 4               6th Division  1948-01-01  Concrete   204.0             85.0
#
#    schools_count  school_score  total_population  ...       neighborhood  \
# 0            0.0         100.0             367.0  ...      South Oakland
# ...

# %%
neighborhoodCounts = pd.DataFrame(df['neighborhood'].value_counts())
neighborhoodCounts.rename(columns = {'neighborhood':'Stairways'}, inplace = True)
neighborhoodCounts.head(60)
# Out:
#                           Stairways
# South Side Slopes               106
# Mount Washington                 51
# Beechview                        42
# Greenfield                       40
# Perry North                      37
# Brookline                        36
# Sheraden                         34
# Carrick                          33
# Perry South                      33
# Elliott                          33
# Marshall-Shadeland               31
# Beltzhoover                      27
# Squirrel Hill South              24
# Duquesne Heights                 22
# Highland Park                    21
# Hazelwood                        21
# Spring Hill-City View            19
# Allentown                        19
# Polish Hill                      19
# Fineview                         17
# Overbrook                        17
# Upper Hill                       16
# Arlington                        15
# Troy Hill                        15
# Garfield                         14
# ...

# %%
neighborhoodCounts.head(65).plot.bar()
plt.rcParams["figure.figsize"] = (30,30)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Preetam's Dataset:**

# %%
data = pd.read_csv("https://data.wprdc.org/datastore/dump/0f214885-ff3e-44e1-9963-e9e9062a04d1")
data
# Out:
#          neighborhood_municipality  indv_tested  cases  deaths update_date
# 0                           Aleppo          389     14       0  2020-11-16
# 1    Allegheny Center (Pittsburgh)          233     23       0  2020-11-16
# 2      Allegheny West (Pittsburgh)          121      5       0  2020-11-16
# 3           Allentown (Pittsburgh)          374     38       0  2020-11-16
# 4           Arlington (Pittsburgh)          306     32       1  2020-11-16
# ..                             ...          ...    ...     ...         ...
# 216                      Whitehall         3009    473       9  2020-11-16
# 217                        Wilkins         1170     74       0  2020-11-16
# 218                    Wilkinsburg         3199    237       9  2020-11-16
# 219                     Wilmerding          297     30       0  2020-11-16
# 220           Windgap (Pittsburgh)          203     18       0  2020-11-16
#
# [221 rows x 5 columns]

# %%
cases = data.drop(columns=['update_date','indv_tested'])
data1 = cases.sort_values('cases',ascending=True)
data1_1 = data1.head(110)
data1_2 = data1.tail(110)

# %%
data1_1.plot(figsize=(20,10),kind='bar',stacked=True,x='neighborhood_municipality',title='COVID-19 Cases and Deaths Based on Neighborhood').legend(bbox_to_anchor=(1.5,1))

# %%
data1_2.plot(figsize=(20,10),kind='bar',stacked=True,x='neighborhood_municipality',title='COVID-19 Cases and Deaths Based on Neighborhood').legend(bbox_to_anchor=(1.5,1))

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Grace's Dataset:**

# %%
dtype={'police_zone': 'string'}
low_memory=False

pgh_trees_data = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da",index_col="id")
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Creating a query mask that consists of only the police zone 
query_mask = pgh_trees_data[['police_zone']]

# Loops through the dataset and counts up every instance of a tree in each zone, prints it out
zone_1 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 1):
        zone_1 = zone_1 + 1    
print("Total number of trees in zone 1:" , 45710 - zone_1)

zone_2 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 2):
        zone_2 = zone_2 + 1    
print("Total number of trees in zone 2:" , 45710 - zone_2)

zone_3 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 3):
        zone_3 = zone_3 + 1    
print("Total number of trees in zone 3:" , 45710 - zone_3)

zone_4 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 4):
        zone_4 = zone_4 + 1    
print("Total number of trees in zone 4:" , 45710 - zone_4)

zone_5 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 5):
        zone_5 = zone_5 + 1    
print("Total number of trees in zone 5:" , 45710 - zone_5)

zone_6 = 0
for row in range (0, 45709):
    temp = query_mask.iat[row, 0]
    if (temp != 6):
        zone_6 = zone_6 + 1    
print("Total number of trees in zone 6:" , 45710 - zone_6)
# Out:
# Total number of trees in zone 1: 7186
# Total number of trees in zone 2: 5124
# Total number of trees in zone 3: 4866
# Total number of trees in zone 4: 14576
# Total number of trees in zone 5: 10161
# Total number of trees in zone 6: 3543

# %%
#my_plot = query_mask.plot(kind='bar')

#my_plot.set_xlabel("Police Zones")
#my_plot.set_ylabel("Number of Trees")

df1 = pd.DataFrame({'Police Zone' : [1.,2.,3.,4.,5.,6.] ,'Number of Trees' : [7186., 5124., 4866., 14576., 10161., 3543.]})

my_plot=  df1.plot(kind='bar')

# %% [markdown]
# This dataset did not group by specific neighborhood, but it did specify which police zones each tree is located in. Here is a key for which police zones correlate to each Pittsburgh neighborhood:
#
# Zone 1 - Brighton Heights, Manchesster, Perry South
# Zone 2 - Polish Hill, Hill District, Strip District, Downtown
# Zone 3 - South Side and Mt. Washington
# Zone 4 - Squirrel Hill North and South
# Zone 5 - East Liberty and Highland Park
# Zone 6 - Crafton Heights, Elliott, Duquesne Heights

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Group Conclusions:**

# %% [markdown]
# **Adnaan:** From this data I have come to the individual conclusion that COVID-19 cases are the most important dataset for us to draw our conclusion from. Our data clearly shows a correlation between exercise (stairways) and air quality (determined by trees) having an impact on Covid cases as well as deaths. This is why the best neighborhood to live in from a health standpoint, in my opinion, is Squirrel Hill.

# %% [markdown]
# **Preetam:** After examining this data, it can be seen that Squirrel Hill is the best neighborhood when talking about exercise and health. Although Squirrel Hill had more cases than other neighborhoods, when comparing the number of cases to the population, it is quite low and the neighborhood consists of a majority of senior citizens who are most vulnerable to the virus. When also looking at the stairways and trees, it can be seen that the neighborhood consists of a lot of trees and a considerable amount of stairways which is good for one's health and exercise. So keeping all this in mind, the best neighborhood to live in from a health standpoint is Squirrel Hill.

# %% [markdown]
# **Grace:** By looking at this data, I was able to conclude that Squirrel Hill is the best neighborhood when considering all the metrics mentioned in the README and comparing them to other neighborhoods in Allegheny County.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
